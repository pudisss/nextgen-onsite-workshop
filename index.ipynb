# %%
import pandas as pd

file = pd.read_csv("./submission.csv")

# %%
file = file.drop("audio name", axis=1)

# %%
file = file[["image name", "Object_Type", "distance", "Location_Zone", "Illumination"]]

# %%
file
# Out:
#                                     image name         Object_Type  distance  \
# 0     a3a9173b-cbdc-41fe-bc5d-3dfb6f8dec5e.png          Clear Path  3.276490
# 1     f4e9acca-e50f-48d9-b6d2-247bdf7975e8.png          Clear Path  2.788393
# 2     2571812c-24c3-438c-baca-e02cec49d213.png          Structural  2.744184
# 3     3d5e66e7-da5f-44be-879d-75a5ad7c62a4.png          Clear Path  1.067087
# 4     ab576c52-d86d-45a9-b4ed-be35cf6cde1f.png  Small/Low Obstacle  3.266430
# ...                                        ...                 ...       ...
# 1995  9418f1e4-afb6-4b1e-8d62-d4bcf603acb7.png          Clear Path  3.523570
# 1996  5cb7e66c-786b-4244-a4a0-53e3cd396629.png          Clear Path  3.146765
# 1997  629a07b8-2425-44c9-8beb-edd35aed5a7c.png          Structural  3.377526
# 1998  46418555-9aab-47dc-92da-a69265087d3f.png    Elevation Change  2.048772
# 1999  bfb343e4-9801-4736-82a9-c8932f40fa29.png          Structural  2.302942
#
#      Location_Zone Illumination
# ...

# %%
file.to_csv("./sub.csv", index=False)
